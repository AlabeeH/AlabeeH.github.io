# %% [markdown]
# # Intro to Python
# - [Input and Output](#Input-and-Output)
# - [Python Variables](Python-Variables)
# - [Arithemtic and Boolean Operators](#Arithemetic-and-Boolean-Operators)

# %%
input()
# Out:
#  Hi there!
# 'Hi there!'

# %%
input("Please type your name:")
# Out:
# Please type your name: Alabee
# 'Alabee'

# %%
print("Hi there!")
# Out:
# Hi there!

# %%
print("AAAA" "BBBB" "CCCCC")
# Out:
# AAAABBBBCCCCC

# %%
print("ABCD")
# Out:
# ABCD

# %% [markdown]
# ## Python Variable

# %%
a="This is a sentence."
b = "cat"
c = "Q"
d = 8
ABCD = "ABCD"
radius = 10
square10 = 5

# %%
print(a)
# Out:
# This is a sentence.

# %%
print(b,c,d)
# Out:
# cat Q 8

# %%
ABCD
# Out:
# 'ABCD'

# %%
type(a)
# Out:
# str

# %%
type(radius)
# Out:
# int

# %%
b="This is another sentence,"

# %%
b
# Out:
# 'This is another sentence,'

# %%
print(b)
# Out:
# This is another sentence,

# %%
name=input("Type your name here:")
# Out:
# Type your name here: Alabee

# %%
print(name)
# Out:
# Alabee

# %% [markdown]
# # Arithmetic and Boolean Operators

# %%
5+7
# Out:
# 12

# %%
5-7
# Out:
# -2

# %%
5*7
# Out:
# 35

# %%
5/7
# Out:
# 0.7142857142857143

# %%
55//7
# Out:
# 7

# %%
55%7
# Out:
# 6

# %%
3**8
# Out:
# 6561

# %%
5**2*(8+6)/14
# Out:
# 25.0

# %%
7+25/5+4
# Out:
# 16.0

# %%
d
# Out:
# 8

# %%
d+=1

# %%
d
# Out:
# 9

# %%
d==4
# Out:
# False
